# %%
import cv2
import os
os.chdir('C:/Users/Indium Software/Documents/MEGA/NASSCOM/Face Detection/Images')

# %%
img=cv2.imread('np4.jfif')

# %%
import numpy
import sys
numpy.set_printoptions(threshold=sys.maxsize)
numpy.set_printoptions( linewidth=125)

# %%
img
# Out:
# array([[[210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [211, 211, 211],
#         [211, 211, 211],
#         [211, 211, 211],
#         [211, 211, 211],
#         [211, 211, 211],
#         [211, 211, 211],
#         [211, 211, 211],
#         [211, 211, 211],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
# ...

# %%
img.shape
# Out:
# (246, 205, 3)

# %%
img[:,:,2]
# Out:
# array([[210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210,
#         210, 211, 211, 211, 211, 211, 211, 211, 211, 210, 210, 210, 210, 210, 210, 210, 210, 211, 211, 211, 211, 211, 211,
#         211, 211, 211, 211, 211, 211, 211, 211, 211, 211, 206, 206, 207, 208, 209, 210, 211, 211, 207, 208, 210, 211, 211,
#         211, 211, 211, 219, 213, 208, 208, 211, 212, 210, 207, 204, 207, 210, 213, 213, 210, 206, 203, 197, 194, 198, 205,
#         203, 194, 194, 201, 191, 196, 202, 204, 201, 198, 197, 197, 200, 203, 206, 205, 202, 202, 206, 211, 213, 213, 211,
#         210, 209, 208, 208, 208, 206, 206, 206, 206, 206, 206, 206, 206, 207, 207, 207, 207, 207, 207, 207, 207, 206, 206,
#         206, 206, 206, 206, 206, 206, 205, 205, 205, 205, 204, 204, 204, 203, 205, 205, 205, 205, 205, 205, 205, 205, 203,
#         203, 203, 203, 203, 203, 203, 203, 202, 202, 202, 201, 201, 200, 200, 200, 201, 201, 201, 201, 201, 201, 201, 201,
# ...

# %%
img2 = img[1:200,:,:]

# %%
from PIL import Image
img3 = Image.fromarray(img2, 'RGB')
img3.save('my.png')
img3.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(img[:,:,1])

# %%
image = [[10,10,10,0,0,0],
    [10,10,10,0,0,0],
    [10,10,10,0,0,0],
    [10,10,10,0,0,0],
    [10,10,10,0,0,0],
    [10,10,10,0,0,0]]

# %%
plt.imshow(m)

# %%
filter =[[1,0,-1],
        [1,0,-1],
        [1,0,-1]]

# %%
plt.imshow(filter)

# %%
result = [[0,30,30,0],
         [0,30,30,0],
         [0,30,30,0],
         [0,30,30,0]]

# %%
plt.imshow(result)
